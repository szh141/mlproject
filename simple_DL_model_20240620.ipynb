# %% [markdown]
# <a href="https://colab.research.google.com/github/szh141/mlproject/blob/main/simple_DL_model_20240620.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://python.plainenglish.io/python-getting-started-with-deep-learning-1-3dde7f4a8c13

# %%
import numpy as np

# Generate some sample data
X_train = np.random.rand(100, 10)  # 100 samples, 10 features
y_train = np.random.randint(2, size=(100,))  # Binary classification labels

# Generate sample test data
X_test = np.random.rand(20, 10)  # 20 samples, 10 features
y_test = np.random.randint(2, size=(20,))  # Binary classification labels

# %%
# import libraries
from keras.models import Sequential
from keras.layers import Dense, Activation

# %%
# Define the model
model = Sequential()
model.add(Dense(units=8, activation='relu', input_shape=(10,)))  # Hidden layer with 8 neurons
model.add(Dense(units=1, activation='sigmoid'))  # Output layer with 1 neuron for binary classification

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 8)                 88
#
#  dense_1 (Dense)             (None, 1)                 9
#
# ...
# Total params: 97 (388.00 Byte)
# Trainable params: 97 (388.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32, verbose=0)

# %%
# evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# 1/1 [==============================] - 0s 303ms/step - loss: 0.6743 - accuracy: 0.6500
# Test Loss: 0.6743336319923401
# Test Accuracy: 0.6499999761581421

# %%
y_pred = model.predict(X_test)
print(y_pred)
# y_pred will be a NumPy array of shape (20,),
# containing the predicted class labels (either 0 or 1)
# for each of the 20 test samples.
# Out:
# 1/1 [==============================] - 0s 157ms/step
# [[0.43562117]
#  [0.5697217 ]
#  [0.56605947]
#  [0.49983805]
#  [0.49400115]
#  [0.51713794]
#  [0.5585283 ]
#  [0.43285134]
#  [0.5339051 ]
#  [0.38635316]
#  [0.47918347]
#  [0.5776246 ]
#  [0.4306362 ]
#  [0.56727016]
#  [0.5796542 ]
#  [0.5853941 ]
#  [0.47910455]
#  [0.56267685]
#  [0.49414462]
#  [0.5099288 ]]
