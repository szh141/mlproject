# %% [markdown]
# <a href="https://colab.research.google.com/github/szh141/mlproject/blob/main/Classification_report_20240524.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://medium.com/@chanakapinfo/classification-report-explained-precision-recall-accuracy-macro-average-and-weighted-average-8cd358ee2f8a

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.metrics import  classification_report
print(classification_report(y_test,y_preds))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-739004833493> in <cell line: 2>()
#       1 from sklearn.metrics import  classification_report
# ----> 2 print(classification_report(y_test,y_preds))
#
# NameError: name 'y_test' is not defined

# %% [markdown]
# ![image.png](data:image/png;base64,...)
